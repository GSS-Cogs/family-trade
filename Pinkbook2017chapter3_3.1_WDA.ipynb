# %% [markdown]
# ###  Pinkbook2017_3.1

# %%
from databaker.framework import *

# %%
import pandas as pd

# %%
import io
import requests
from pathlib import Path

# %%
Url = 'https://drive.google.com/uc?export=download&id=16CpeYtvRxkvyt2RUkSAzTBGEJX_DnNLm'

# %%
df = pd.read_excel(Url, sheetname='3.1', header=None)

# %%
df
# Out:
#            0                                                  1      2   \
# 0         3.1                                  Trade in services    NaN
# 1         NaN                                      Summary table    NaN
# 2         NaN                                                NaN    NaN
# 3         NaN                                                NaN    NaN
# 4         NaN                                                NaN    NaN
# 5                                              Exports (Credits)
# 6         NaN                                                NaN    NaN
# 7                 Manufacturing on physical inputs owned by o...   MEX3
# 8                                         Maintenance and repair   MEY3
# 9                                                      Transport   FJOD
# 10                                                        Travel   FJPF
# 11                                                  Construction   FJPI
# ...

# %%
df.to_excel('PB2017_3.1.xls',index=False)

# %%
tab = loadxlstabs('PB2017_3.1.xls')
# Out:
# Loading PB2017_3.1.xls which has size 13824 bytes
# Table names: ['Sheet1']

# %%
tab = tab[0]
savepreviewhtml(tab)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Sheet1</caption>
# ...

# %%
observations = tab.excel_ref('D8').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
Code = tab.excel_ref('C8').expand(DOWN).is_not_blank()

# %%
Year = tab.excel_ref('D5').expand(RIGHT).is_not_blank()

# %%
Transactions = tab.excel_ref('B').expand(DOWN).by_index([7,24,41]) - tab.excel_ref('B57').expand(DOWN)

# %%
Services = tab.excel_ref('B').expand(DOWN).is_not_blank().is_not_whitespace() - Transactions - tab.excel_ref('B2').expand(UP)

# %%
Currency = tab.excel_ref('W3')

# %%
Dimensions = [
            HDimConst('GEOG', 'K02000001'),
            HDim(Year,'Year', DIRECTLY,ABOVE),
            HDim(Code,'Cdid',DIRECTLY,LEFT),
            HDimConst('Currency', 'Pounds(millions)'),            
            HDim(Services, 'Type of Services', DIRECTLY, LEFT),
            HDim(Transactions,'Transactions',CLOSEST, ABOVE)           
    
]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)

# %%
savepreviewhtml(c1)
# Out:
# <div id="injblock1004">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc2" style="background-color:MistyRose">Year</td><td class="xc3" style="background-color:LightGray">Cdid</td><td class="xc5" style="background-color:Coral">Type of Services</td><td class="xc6" style="background-color:Gold">Transactions</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Sheet1</caption>
# ...

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS DATAMARKER       GEOG    Year   Cdid          Currency  \
# 0                   -  K02000001  1997.0   MEX3  Pounds(millions)
# 1                   -  K02000001  1998.0   MEX3  Pounds(millions)
# 2                   -  K02000001  1999.0   MEX3  Pounds(millions)
# 3                   -  K02000001  2000.0   MEX3  Pounds(millions)
# 4                   -  K02000001  2001.0   MEX3  Pounds(millions)
# 5                   -  K02000001  2002.0   MEX3  Pounds(millions)
# 6       86        NaN  K02000001  2003.0   MEX3  Pounds(millions)
# 7       89        NaN  K02000001  2004.0   MEX3  Pounds(millions)
# 8      115        NaN  K02000001  2005.0   MEX3  Pounds(millions)
# 9      135        NaN  K02000001  2006.0   MEX3  Pounds(millions)
# 10     197        NaN  K02000001  2007.0   MEX3  Pounds(millions)
# 11     343        NaN  K02000001  2008.0   MEX3  Pounds(millions)
# 12     361        NaN  K02000001  2009.0   MEX3  Pounds(millions)
# ...

# %%
new_table = new_table.drop('DATAMARKER', axis=1)

# %%
new_table['TIME'] = new_table['Year'].map(lambda cell:cell.replace('.0', ''))
new_table
# Out:
#        OBS       GEOG    Year   Cdid          Currency  \
# 0           K02000001  1997.0   MEX3  Pounds(millions)
# 1           K02000001  1998.0   MEX3  Pounds(millions)
# 2           K02000001  1999.0   MEX3  Pounds(millions)
# 3           K02000001  2000.0   MEX3  Pounds(millions)
# 4           K02000001  2001.0   MEX3  Pounds(millions)
# 5           K02000001  2002.0   MEX3  Pounds(millions)
# 6       86  K02000001  2003.0   MEX3  Pounds(millions)
# 7       89  K02000001  2004.0   MEX3  Pounds(millions)
# 8      115  K02000001  2005.0   MEX3  Pounds(millions)
# 9      135  K02000001  2006.0   MEX3  Pounds(millions)
# 10     197  K02000001  2007.0   MEX3  Pounds(millions)
# 11     343  K02000001  2008.0   MEX3  Pounds(millions)
# 12     361  K02000001  2009.0   MEX3  Pounds(millions)
# 13     445  K02000001  2010.0   MEX3  Pounds(millions)
# 14     502  K02000001  2011.0   MEX3  Pounds(millions)
# 15     597  K02000001  2012.0   MEX3  Pounds(millions)
# ...

# %%
new_table = new_table.drop('Year', axis=1)

# %%
print(len(new_table))
new_table
# Out:
# 780
#        OBS       GEOG   Cdid          Currency  \
# 0           K02000001   MEX3  Pounds(millions)
# 1           K02000001   MEX3  Pounds(millions)
# 2           K02000001   MEX3  Pounds(millions)
# 3           K02000001   MEX3  Pounds(millions)
# 4           K02000001   MEX3  Pounds(millions)
# 5           K02000001   MEX3  Pounds(millions)
# 6       86  K02000001   MEX3  Pounds(millions)
# 7       89  K02000001   MEX3  Pounds(millions)
# 8      115  K02000001   MEX3  Pounds(millions)
# 9      135  K02000001   MEX3  Pounds(millions)
# 10     197  K02000001   MEX3  Pounds(millions)
# 11     343  K02000001   MEX3  Pounds(millions)
# 12     361  K02000001   MEX3  Pounds(millions)
# 13     445  K02000001   MEX3  Pounds(millions)
# 14     502  K02000001   MEX3  Pounds(millions)
# 15     597  K02000001   MEX3  Pounds(millions)
# 16    2556  K02000001   MEX3  Pounds(millions)
# 17    2103  K02000001   MEX3  Pounds(millions)
# 18    2191  K02000001   MEX3  Pounds(millions)
# ...

# %%
new_table['Type of Services'] = new_table['Type of Services'].str.strip()

# %%
new_table['TIME'] = new_table['TIME'].str.strip()

# %%
new_table['GEOG'] = new_table['GEOG'].str.strip()

# %%
new_table['Currency'] = new_table['Currency'].str.strip()

# %%
new_table['Cdid'] = new_table['Cdid'].str.strip()

# %%
new_table['Transactions'] = new_table['Transactions'].str.strip()

# %%
new_table.dtypes
# Out:
# OBS                 object
# GEOG                object
# Cdid                object
# Currency            object
# Type of Services    object
# Transactions        object
# TIME                object
# dtype: object

# %%
new_table.to_csv('C:\\Users\\vamsi\\Desktop\\Gdrive\\Out\\Mret\\pinkbook2017chapter3_3.1.tidydata.csv', index = False)

# %%
# new_table.fillna('', inplace=True)

# writetechnicalCSV('C:\\Users\\vamsi\\Desktop\\Gdrive\\Out\\Mret\\pinkbook2017chapter3_3.1.csv', new_table)
# Out:
# writing 1 conversion segments into C:\Users\vamsi\Desktop\Gdrive\Out\Mret\pinkbook2017chapter3_3.1.csv
# pdconversionwrite segment size 780

# %%
# DF = pd.read_csv('C:\\Users\\vamsi\\Desktop\\Gdrive\\Out\\Mret\\pinkbook2017chapter3_3.1.csv')

# %%
# DF
# Out:
#     observation  data_marking  statistical_unit_eng  statistical_unit_cym  \
# 0           NaN           NaN                   NaN                   NaN
# 1           NaN           NaN                   NaN                   NaN
# 2           NaN           NaN                   NaN                   NaN
# 3           NaN           NaN                   NaN                   NaN
# 4           NaN           NaN                   NaN                   NaN
# 5           NaN           NaN                   NaN                   NaN
# 6          86.0           NaN                   NaN                   NaN
# 7          89.0           NaN                   NaN                   NaN
# 8         115.0           NaN                   NaN                   NaN
# 9         135.0           NaN                   NaN                   NaN
# 10        197.0           NaN                   NaN                   NaN
# 11        343.0           NaN                   NaN                   NaN
# ...

# %%
# pd.options.display.max_rows = 999

# %%
# pd.options.display.max_columns = 999

# %%
# DF
# Out:
#     observation  data_marking  statistical_unit_eng  statistical_unit_cym  \
# 0           NaN           NaN                   NaN                   NaN
# 1           NaN           NaN                   NaN                   NaN
# 2           NaN           NaN                   NaN                   NaN
# 3           NaN           NaN                   NaN                   NaN
# 4           NaN           NaN                   NaN                   NaN
# 5           NaN           NaN                   NaN                   NaN
# 6          86.0           NaN                   NaN                   NaN
# 7          89.0           NaN                   NaN                   NaN
# 8         115.0           NaN                   NaN                   NaN
# 9         135.0           NaN                   NaN                   NaN
# 10        197.0           NaN                   NaN                   NaN
# 11        343.0           NaN                   NaN                   NaN
# ...

# %%
# DF.drop('cdid', axis =1, inplace = True)
# DF.drop('unit_multiplier', axis =1, inplace = True)

# %%
# DF.drop(['dim_id_1','dimension_label_eng_1',
#         'dimension_label_cym_1', 'dimension_item_label_eng_1', 
#         'dimension_item_label_cym_1' ,    
#         'dim_id_2', 'dimension_label_eng_2', 
#         'dimension_item_label_eng_2','dimension_item_label_cym_2','is_total_1','is_sub_total_1',
#         'time_dim_item_label_eng','time_dim_item_label_cym' ],
#          axis = 1, inplace =True)

# %%
# DF.rename(index=str, columns={"dim_item_id_1": "cdid"}, inplace = True)

# %%
# DF.rename(index=str, columns={"dim_item_id_2": "unit_multiplier"}, inplace = True)

# %%
# DF['dimension_item_label_eng_1'] = ''

# %%
# DF.to_csv('C:\\Users\\vamsi\\Desktop\\Gdrive\\Out\\Mret\\pinkbook2017chapter3_3.1.csv', index = False)
