# %% [markdown]
# ###  Pinkbook2017_3.6

# %%
from databaker.framework import *

# %%
import pandas as pd

# %%
import io
import requests
from pathlib import Path

# %%
Url = 'https://drive.google.com/uc?export=download&id=16CpeYtvRxkvyt2RUkSAzTBGEJX_DnNLm'

# %%
df = pd.read_excel(Url, sheetname='3.6', header=None)

# %%
df
# Out:
#            0                                                  1      2   \
# 0         3.6                           Intellectual property1,2    NaN
# 1         NaN                                                NaN    NaN
# 2         NaN                                                NaN    NaN
# 3         NaN                                                NaN    NaN
# 4                                              Exports (Credits)
# 5         NaN                                                NaN    NaN
# 6                                       Franchise and trademarks   EAI5
# 7                           Outcomes of research and development   EAI7
# 8                              Distribution of computer software   FJFN
# 9                 Distribution of audio-visual and related pr...   FJFO
# 10        NaN                                                NaN    NaN
# 11                                                         Total   FJPM
# ...

# %%
df.to_excel('PB2017_3.6.xls',index=False)

# %%
tab = loadxlstabs('PB2017_3.6.xls')
# Out:
# Loading PB2017_3.6.xls which has size 9728 bytes
# Table names: ['Sheet1']

# %%
tab = tab[0]
savepreviewhtml(tab)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Sheet1</caption>
# ...

# %%
observations = tab.excel_ref('D8').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
Code = tab.excel_ref('C8').expand(DOWN).is_not_blank()

# %%
Year = tab.excel_ref('D4').expand(RIGHT).is_not_blank()

# %%
Commerce = tab.excel_ref('B').expand(DOWN).by_index([6,15,24]) - tab.excel_ref('B32').expand(DOWN)

# %%
# Financialservices = tab.excel_ref('B').expand(DOWN).by_index([8,29,38,42,51,58,62,69,71,72]) - tab.excel_ref('B73').expand(DOWN)

# %%
Revenue = tab.excel_ref('B').expand(DOWN).is_not_blank().is_not_whitespace() - Commerce

# %%
Currency = tab.excel_ref('W3')

# %%
Dimensions = [
            HDimConst('GEOG', 'K02000001'),
            HDim(Year,'TIME', DIRECTLY,ABOVE),
            HDim(Code,'Cdid',DIRECTLY,LEFT),
            HDimConst('Currency', 'Pounds(millions)'),            
            HDim(Revenue, 'Intellectual property Revenue', DIRECTLY, LEFT),
            HDim(Commerce,'Commerce', CLOSEST, ABOVE)    
]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)

# %%
savepreviewhtml(c1)
# Out:
# <div id="injblock1002">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc2" style="background-color:MistyRose">TIME</td><td class="xc3" style="background-color:LightGray">Cdid</td><td class="xc5" style="background-color:Coral">Intellectual property Revenue</td><td class="xc6" style="background-color:Gold">Commerce</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Sheet1</caption>
# ...

# %%
new_table = c1.topandas()
new_table
# Out:
# TIMEUNIT='Year'
#       OBS DATAMARKER       GEOG  TIME TIMEUNIT   Cdid          Currency  \
# 0                  -  K02000001  1997     Year   EAI5  Pounds(millions)
# 1                  -  K02000001  1998     Year   EAI5  Pounds(millions)
# 2                  -  K02000001  1999     Year   EAI5  Pounds(millions)
# 3                  -  K02000001  2000     Year   EAI5  Pounds(millions)
# 4                  -  K02000001  2001     Year   EAI5  Pounds(millions)
# 5    3145        NaN  K02000001  2002     Year   EAI5  Pounds(millions)
# 6    3431        NaN  K02000001  2003     Year   EAI5  Pounds(millions)
# 7    3733        NaN  K02000001  2004     Year   EAI5  Pounds(millions)
# 8    1911        NaN  K02000001  2005     Year   EAI5  Pounds(millions)
# 9    1630        NaN  K02000001  2006     Year   EAI5  Pounds(millions)
# 10   1572        NaN  K02000001  2007     Year   EAI5  Pounds(millions)
# 11   1798        NaN  K02000001  2008     Year   EAI5  Pounds(millions)
# ...

# %%
new_table = new_table.drop('TIMEUNIT', axis=1)
new_table = new_table.drop('DATAMARKER', axis=1)

# %%
print(len(new_table))
new_table
# Out:
# 300
#       OBS       GEOG  TIME   Cdid          Currency  \
# 0          K02000001  1997   EAI5  Pounds(millions)
# 1          K02000001  1998   EAI5  Pounds(millions)
# 2          K02000001  1999   EAI5  Pounds(millions)
# 3          K02000001  2000   EAI5  Pounds(millions)
# 4          K02000001  2001   EAI5  Pounds(millions)
# 5    3145  K02000001  2002   EAI5  Pounds(millions)
# 6    3431  K02000001  2003   EAI5  Pounds(millions)
# 7    3733  K02000001  2004   EAI5  Pounds(millions)
# 8    1911  K02000001  2005   EAI5  Pounds(millions)
# 9    1630  K02000001  2006   EAI5  Pounds(millions)
# 10   1572  K02000001  2007   EAI5  Pounds(millions)
# 11   1798  K02000001  2008   EAI5  Pounds(millions)
# 12   2504  K02000001  2009   EAI5  Pounds(millions)
# 13   2607  K02000001  2010   EAI5  Pounds(millions)
# 14   2130  K02000001  2011   EAI5  Pounds(millions)
# 15   2527  K02000001  2012   EAI5  Pounds(millions)
# 16   4388  K02000001  2013   EAI5  Pounds(millions)
# ...

# %%
new_table['TIME'] = new_table['TIME'].str.strip()
new_table['GEOG'] = new_table['GEOG'].str.strip()
new_table['Currency'] = new_table['Currency'].str.strip()
new_table['Cdid'] = new_table['Cdid'].str.strip()

# %%
new_table['Commerce'] = new_table['Commerce'].str.strip()

# %%
new_table['Intellectual property Revenue'] = new_table['Intellectual property Revenue'].str.strip()

# %%
new_table.to_csv('C:\\Users\\vamsi\\Desktop\\Gdrive\\Out\\Mret\\pinkbook2017chapter3_3.6.tidydata.csv', index = False)
