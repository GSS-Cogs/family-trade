# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://www.ons.gov.uk/file?uri=/businessindustryandtrade/internationaltrade/datasets/internationaltradeinservicesreferencetables/alltables2016/internationaltradeinservices2016.xls'
    inputFile = sourceFolder / 'internationaltradeinservices2016.xlsb'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table C7 2013-2016')[0]
# Out:
# Loading in\internationaltradeinservices2016.xlsb which has size 750080 bytes
# Table names: ['Table C7 2013-2016']

# %%
observations = tab.excel_ref('E6').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
Year = tab.excel_ref('E4').expand(RIGHT).is_not_whitespace()

# %%
Flow = tab.excel_ref('E3').expand(RIGHT).is_not_blank()

# %%
geo1 = tab.excel_ref('A5').expand(DOWN).is_not_blank() - tab.excel_ref('A94').expand(DOWN)
geo1
# Out:
# {<A73 'Merchanting and Other Trade related Services'>, <A88 'Technical and Scientific Services'>, <A49 'Telecommunication, Computer and Information Services'>, <A36 'Intellectual Property'>, <A5 'Agricultural and Mining Services'>, <A16 'Business and Professional Services'>, <A58 'Construction Services'>, <A68 'Insurance and Pension Services'>, <A10 'Manufacturing, Maintenance and On-site Processing Services'>, <A79 'Personal, Cultural and Recreational  Services'>, <A30 'Research and Development Services'>, <A64 'Financial Services'>}

# %%
geo3 = tab.excel_ref('C5').expand(DOWN).is_not_blank() - tab.excel_ref('A94').expand(DOWN)
geo3
# Out:
# {<C23 'Operating leasing services'>, <C11 'Waste treatment and depolution services'>, <C51 'Telecommunications'>, <C82 'Training and educational services'>, <C81 'Medical Services'>, <C91 'Scientific and other techinical services inc surveying'>, <C21 'Recruitment services'>, <C41 'Outright sales and purchases '>, <C27 'Services between related enterprises'>, <C18 'Advertising, market research and public opinion polling services'>, <C52 'Computer Services'>, <C12 'Manufacturing services on goods owned by others'>, <C39 'Charges or payments for the use of '>, <C65 'Financial'>, <C80 'Audio- Visual and related services '>, <C59 'Construction in the UK'>, <C75 'Other trade - related services'>, <C69 'Insurance and Pension Services Claims'>, <C25 'Property management services'>, <C95 'Other trade in services'>, <C31 'Provision of R&D services'>, <C20 'Public relations services'>, <C22 'Legal services'>, <C44 'Outright sales and purchases '>, <C83 'Heritage and recreational services'>, <C90 'Engineering Services'>, <C6 'Agricultural, forestry and fishing'>, <C74 'Merchanting'>, <C26 'Other business and professional services'>, <C53 'Publishing Services'>, <C13 'Maintenance and repair services'>, <C19 'Business management and management consulting services'>, <C38 'Outright sales and purchases '>, <C50 'Postal and courier'>, <C60 'Construction outside the UK'>, <C45 'Charges or payments for the use of '>, <C17 'Accountancy, auditing, bookkeeping and tax consulting services'>, <C55 'Information Services'>, <C24 'Procurement services'>, <C84 'Social, domestic and other personal services'>, <C32 'Provision of product development and testing activities'>, <C42 'Charges or payments for the use of '>, <C89 'Architectural services'>, <C70 'Insurance and Pension Services Premiums'>, <C7 'Mining and oil and gas extraction services'>, <C54 'News agency Services'>}

# %%
Dimensions = [
            HDim(Year,'Year',DIRECTLY,ABOVE),
            HDim(geo1,'geo1',CLOSEST,ABOVE),
#             HDim(geo2,'geo2',DIRECTLY,LEFT),
            HDim(geo3,'geo3',DIRECTLY,LEFT),
            HDim(Flow, 'Flow',CLOSEST,LEFT),
            HDimConst('Measure Type', 'GBP Total'),
            HDimConst('Unit','gbp-million')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
if is_interactive():
    savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# td.xb { font-weight: bold }
# td.xn { color: green }
# td.xd { color: purple }
# span.xo { text-decoration: line-through; }
# span.xn { }
# table { border-collapse: collapse }
# td.xc0 { background-color: Aqua }
# td.xc1 { background-color: LightGreen }
# td.xc2 { background-color: MistyRose }
# td.xc3 { background-color: LightGray }
# td.xc4 { background-color: BurlyWood }
# td.xc5 { background-color: Coral }
# td.xc6 { background-color: Gold }
# td.xc7 { background-color: Lime }
# td.xc8 { background-color: LightBlue }
# td.xc9 { background-color: Plum }
# td.xc10 { background-color: CornflowerBlue }
# td.xc11 { background-color: LightYellow }
# td.xc12 { background-color: Lavender }
# td.xc13 { background-color: Violet }
# td.xc14 { background-color: SeaGreen }
# td.xc15 { background-color: DeepSkyBlue }
# td.xc16 { background-color: Blue }
# td.xc17 { background-color: LightGray }
# td.xc18 { background-color: PaleTurquoise }
# td.xc19 { background-color: Tan }
# td.xc20 { background-color: SkyBlue }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { background-color: red; border: thin blue dotted }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0">OBS</td><td class="xc1">Year</td><td class="xc2">geo1</td><td class="xc3">geo3</td><td class="xc4">Flow</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table C7 2013-2016</caption>
# <tr><td class="xb" title="0 0">C7</td><td class="xb" title="1 0"></td><td class="xb" title="2 0">Arts, Entertainment, Recreation and Other Service Activities industry analysed by product 2013 - 2016</td><td class="" title="3 0"></td><td class="" title="4 0"></td><td class="" title="5 0"></td><td class="" title="6 0"></td><td class="" title="7 0"></td><td class="" title="8 0"></td><td class="" title="9 0"></td><td class="" title="10 0"></td><td class="" title="11 0"></td><td class="" title="12 0"></td><td class="" title="13 0"></td><td class="" title="14 0"></td><td class="" title="15 0"></td><td class="" title="16 0"></td><td class="" title="17 0"></td><td class="" title="18 0"></td><td class="" title="19 0"></td><td class="" title="20 0"></td><td class="" title="21 0"></td><td class="" title="22 0"></td><td class="" title="23 0"></td><td class="" title="24 0"></td><td class="" title="25 0"></td><td class="" title="26 0"></td><td class="" title="27 0"></td><td class="" title="28 0"></td><td class="" title="29 0"></td><td class="" title="30 0"></td><td class="" title="31 0"></td><td class="" title="32 0"></td><td class="" title="33 0"></td><td class="" title="34 0"></td><td class="" title="35 0"></td><td class="" title="36 0"></td><td class="" title="37 0"></td><td class="" title="38 0"></td><td class="" title="39 0"></td><td class="" title="40 0"></td><td class="" title="41 0"></td><td class="" title="42 0"></td><td class="" title="43 0"></td><td class="" title="44 0"></td><td class="" title="45 0"></td><td class="" title="46 0"></td><td class="" title="47 0"></td><td class="" title="48 0"></td><td class="" title="49 0"></td></tr>
# <tr><td class="xb" title="0 3"></td><td class="xb" title="1 3"></td><td class="xb" title="2 3"></td><td class="xb" title="3 3"></td><td class="xc1 xb xn" title="4 3">2013.0</td><td class="xc1 xb xn" title="5 3">2014.0</td><td class="xc1 xb xn" title="6 3">2015.0</td><td class="xc1 xb xn" title="7 3">2016.0</td><td class="xb" title="8 3"></td><td class="xc1 xb xn" title="9 3">2013.0</td><td class="xc1 xb xn" title="10 3">2014.0</td><td class="xc1 xb xn" title="11 3">2015.0</td><td class="xc1 xb xn" title="12 3">2016.0</td><td class="xb" title="13 3"></td><td class="xc1 xb xn" title="14 3">2013.0</td><td class="xc1 xb xn" title="15 3">2014.0</td><td class="xc1 xb xn" title="16 3">2015.0</td><td class="xc1 xb xn" title="17 3">2016.0</td><td class="" title="18 3"></td><td class="" title="19 3"></td><td class="" title="20 3"></td><td class="" title="21 3"></td><td class="" title="22 3"></td><td class="" title="23 3"></td><td class="" title="24 3"></td><td class="" title="25 3"></td><td class="" title="26 3"></td><td class="" title="27 3"></td><td class="" title="28 3"></td><td class="" title="29 3"></td><td class="" title="30 3"></td><td class="" title="31 3"></td><td class="" title="32 3"></td><td class="" title="33 3"></td><td class="" title="34 3"></td><td class="" title="35 3"></td><td class="" title="36 3"></td><td class="" title="37 3"></td><td class="" title="38 3"></td><td class="" title="39 3"></td><td class="" title="40 3"></td><td class="" title="41 3"></td><td class="" title="42 3"></td><td class="" title="43 3"></td><td class="" title="44 3"></td><td class="" title="45 3"></t

# %%
new_table = c1.topandas()

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'], errors='coerce').fillna(0)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['geo3'].fillna('Total', inplace = True)

# %%
new_table['BOP Service'] = new_table['geo1'].fillna('') + '-' + new_table['geo3'].fillna('')

# %%
new_table['Flow'] = new_table['Flow'].str.lower()

# %%
new_table['Flow'] = new_table['Flow'].map(lambda cell:cell.replace('balances', 'balance'))

# %%
new_table = new_table[new_table['Value'] != '' ]

# %%
new_table['International Trade Basis'] = 'BOP'

# %%
new_table['ONS Partner Geography'] = 'Whole world'

# %%
new_table = new_table[['ONS Partner Geography', 'Year','Flow','BOP Service', 'International Trade Basis', 'Measure Type','Value','Unit' ]]

# %%
# if is_interactive():
#     SubstancetinationFolder = Path('out')
#     SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
#     new_table.to_csv(SubstancetinationFolder / ('tablec72.csv'), index = False)

# %%
new_table.head()
# Out:
#    ONS Partner Geography  Year     Flow  \
# 20           Whole world  2013  balance
# 24           Whole world  2013  exports
# 32           Whole world  2013  balance
# 48           Whole world  2013  exports
# 51           Whole world  2016  exports
#
#                                           BOP Service  \
# 20  Agricultural and Mining Services-Mining and oi...
# 24             Agricultural and Mining Services-Total
# 32             Agricultural and Mining Services-Total
# 48  Manufacturing, Maintenance and On-site Process...
# 51  Manufacturing, Maintenance and On-site Process...
#
#    International Trade Basis Measure Type    Value         Unit
# 20                       BOP    GBP Total  5.40711  gbp-million
# 24                       BOP    GBP Total  5.41334  gbp-million
# 32                       BOP    GBP Total   5.4071  gbp-million
# 48                       BOP    GBP Total  5.11664  gbp-million
# 51                       BOP    GBP Total        1  gbp-million
