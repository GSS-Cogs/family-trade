# %% [markdown]
# Fetch the source data, in this case from an open shared Google drive. We cache the source data in the `in` directory for further processing and to avoid re-fetching each time this notebook is run.
#
# Note that there appears to be a bug in rdf-tabular where the filenames of CSV files need to be in lower case.

# %%
import requests
from pathlib import Path

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

sources = [
    ('cn8_2012.csv', '1P7YyFF6qXKXWVtR0Vt3kkvFPOjThMQH8'),
    ('cn8_2013.csv', '1de-Le9ungrbdoGyvWI_RwmEhNpTmR-70'),
    ('cn8_2014.csv', '1oC3jlItfsUshd54KOR7yn9NxpR83iCbC'),
    ('cn8_2015.csv', '1H54-FYrCFa1DylCBg38RAPAeCtkGq4la'),
    ('cn8_2016.csv', '11fLsnoiWzTcA1d3nSDWvyrKQEHwIf6Hz')
]

for filename, google_id in sources:
    sourceFile = sourceFolder / filename

    if not (sourceFile.exists() and sourceFile.is_file()):
        response = requests.get(f'https://drive.google.com/uc?export=download&id={google_id}')
        with open(sourceFile, 'wb') as f:
            f.write(response.content)

# %% [markdown]
# This data is already in [Tidy Data format](http://vita.had.co.nz/papers/tidy-data.pdf), but needs some "reconciliation" of the country column in order to corresponding linked data resources for each country name.
#
# We'll use [Getty's Thesaurus of Geographic Names](http://www.getty.edu/research/tools/vocabularies/tgn/index.html) as they provide well curated linked open data.
#
# Getty offers a SPARQL interface with many example queries that could be used to reconcile the given country names. We'll use their [reconciliation service](http://vocab.getty.edu/queries#OpenRefine_Reconciliation_Service) for now.
#
# Other queries worth considering:
# * http://vocab.getty.edu/queries#Places_with_English_or_GVP_Label

# %%
import pandas
import json
import sys
from urllib.parse import quote_plus

countriesFile = Path('metadata') / 'countries.json'
countries = json.load(open(countriesFile))

for filename, google_id in sources:
  table = pandas.read_csv(sourceFolder / filename)
  countryNames = table['country'].unique()

  for country in countryNames:
      if country not in countries:
          try:
              response = requests.get(f'http://vocab.getty.edu/sparql.json?query=select+distinct*{{?x+skos:inScheme+tgn:;(xl:prefLabel|xl:altLabel)/gvp:term"{quote_plus(country)}"@en}}')
              countries[country] = [binding['x']['value'] for binding in response.json()['results']['bindings']]
          except:
              print("Unexpected error for '%s':" % country, sys.exc_info()[0])

with open(countriesFile, 'w') as ctr:
    json.dump(countries, ctr, indent=2)
    
countries
# Out:
# {'Afghanistan': ['http://vocab.getty.edu/tgn/7016612'],
#  'Albania': ['http://vocab.getty.edu/tgn/7006417'],
#  'Algeria': ['http://vocab.getty.edu/tgn/7016752'],
#  'American Samoa': ['http://vocab.getty.edu/tgn/7005667'],
#  'Andorra': ['http://vocab.getty.edu/tgn/1000061'],
#  'Angola': ['http://vocab.getty.edu/tgn/1000149'],
#  'Anguilla': ['http://vocab.getty.edu/tgn/7004637'],
#  'Antarctica': ['http://vocab.getty.edu/tgn/1000007'],
#  'Antigua:Barbuda': ['http://vocab.getty.edu/tgn/1000009'],
#  'Argentina': ['http://vocab.getty.edu/tgn/7006477'],
#  'Armenia': ['http://vocab.getty.edu/tgn/7004538',
#   'http://vocab.getty.edu/tgn/7000529'],
#  'Trinidad:Tobago': ['http://vocab.getty.edu/tgn/7004787'],
#  'Tunisia': ['http://vocab.getty.edu/tgn/1000205'],
#  'Turkey': ['http://vocab.getty.edu/tgn/7821365',
#   'http://vocab.getty.edu/tgn/7821364',
#   'http://vocab.getty.edu/tgn/1000144'],
#  'Turkmenistan': ['http://vocab.getty.edu/tgn/7006659'],
#  'Turks & Caicos': ['http://vocab.getty.edu/tgn/7004630'],
#  'Tuvalu': ['http://vocab.getty.edu/tgn/1000236'],
#  'UAE': ['http://vocab.getty.edu/tgn/1000143'],
#  'US Minor Islands': ['http://vocab.getty.edu/tgn/7023938'],
#  'US Virgin Is': ['http://vocab.getty.edu/tgn/7005118'],
#  'Uganda': ['http://vocab.getty.edu/tgn/1000206'],
#  'Ukraine': ['http://vocab.getty.edu/tgn/7006660'],
#  'United States': ['http://vocab.getty.edu/tgn/7012149'],
#  'Uruguay': ['http://vocab.getty.edu/tgn/1000058'],
#  'Uzbekistan': ['http://vocab.getty.edu/tgn/7006661'],
#  'Vanuatu': ['http://vocab.getty.edu/tgn/1000225'],
#  'Vatican City': ['http://vocab.getty.edu/tgn/7001168'],
#  'Venezuela': ['http://vocab.getty.edu/tgn/1000059'],
#  'Vietnam': ['http://vocab.getty.edu/tgn/1000145'],
#  'Wallis & Futuna': ['http://vocab.getty.edu/tgn/7006219'],
#  'Western Sahara': ['http://vocab.getty.edu/tgn/1000200'],
#  'Yemen': ['http://vocab.getty.edu/tgn/7000261'],
#  'Zambia': ['http://vocab.getty.edu/tgn/1000209'],
#  'Zimbabwe': ['http://vocab.getty.edu/tgn/1000185']}

# %%
tgn = {c: countries[c][0][len('http://vocab.getty.edu/tgn/'):] for c in countries if countries[c] != []}
tgn
# Out:
# {'Afghanistan': '7016612',
#  'Albania': '7006417',
#  'Algeria': '7016752',
#  'American Samoa': '7005667',
#  'Andorra': '1000061',
#  'Angola': '1000149',
#  'Anguilla': '7004637',
#  'Antarctica': '1000007',
#  'Antigua:Barbuda': '1000009',
#  'Argentina': '7006477',
#  'Armenia': '7004538',
#  'Aruba': '7004548',
#  'Australia': '7000490',
#  'Azerbaijan': '7006646',
#  'Bahamas': '7005332',
#  'Bahrain': '7016770',
#  'Bangladesh': '1000105',
#  'Barbados': '7004770',
#  'Belarus': '7006657',
#  'Belize': '7005346',
#  'Benin': '1000160',
#  'Bermuda': '7032026',
#  'Bhutan': '7927800',
#  'Bolivia': '7864299',
#  'Bonaire': '7593113',
#  'Bosnia & Herz.': '7006664',
#  'Botswana': '1000150',
#  'Bouvet Island': '7016858',
#  'Br Ind Oc Terr': '7008651',
#  'Br Virgin Is': '7004677',
#  'Brazil': '1000047',
#  'Brunei': '1000107',
#  'Burkina': '1000208',
#  'Burma': '300343857',
#  'Burundi': '7001630',
#  'Cambodia': '1000109',
#  'Cameroon': '1000153',
#  'Canada': '7743720',
#  'Cape Verde': '7001632',
#  'Cayman Islands': '7004623',
#  'Cent Afr Rep': '1000155',
#  'Ceuta': '7001160',
#  'Chad': '7905337',
#  'Chile': '1000049',
#  'China': '7994975',
#  'Christmas Is': '7004615',
#  'Cocos Islands': '7000429',
#  'Colombia': '1000050',
#  'Comoros': '1000157',
#  'Congo (Dem. Rep)': '300016309',
#  'Congo (Republic)': '1001144',
#  'Cook Islands': '7006213',
#  'Costa Rica': '7005364',
#  'Croatia': '7006663',
#  'Cuba': '7004624',
#  'Djibouti': '7001644',
#  'Dominica': '7004641',
#  'Dominican Rep': '300386023',
#  'Ecuador': '1000051',
#  'Egypt': '7014986',
#  'El Salvador': '7005441',
#  'Equat Guinea': '1000161',
#  'Eritrea': '7001658',
#  'Ethiopia': '7000489',
#  'Falkland Islands': '7005152',
#  'Faroe Islands': '7004167',
#  'Fiji': '7000493',
#  'Fr Southern Terr': '1000163',
#  'French Polynesia': '1000216',
#  'Fyr Macedonia': '300020688',
#  'Gabon': '1000164',
#  'Gambia': '1000165',
#  'Georgia': '7006653',
#  'Ghana': '1000166',
#  'Gibraltar': '7925549',
#  'Greenland': '7851202',
#  'Grenada': '7004771',
#  'Guam': '7000550',
#  'Guatemala': '7005493',
#  'Guinea': '7032931',
#  'Guinea-Bissau': '1000183',
#  'Guyana': '1000054',
#  'Haiti': '7005502',
#  'Heard & Mcdonald': '4000115',
#  'Honduras': '7005554',
#  'Hong Kong': '7004542',
#  'Iceland': '7030364',
#  'India': '7000208',
#  'Indonesia': '1000116',
#  'Iran': '7000231',
#  'Iraq': '1000118',
#  'Israel': '1000119',
#  'Ivory Coast': '7000133',
#  'Jamaica': '7030371',
#  'Japan': '7030366',
#  'Jordan': '7512102',
#  'Kazakhstan': '7014786',
#  'Kenya': '7846789',
#  'Kiribati': '1000217',
#  'Kosovo': '7015191',
#  'Kuwait': '1000124',
#  'Kyrgyz Republic': '7006655',
#  'Laos': '1000125',
#  'Lebanon': '1000126',
#  'Lesotho': '7001660',
#  'Liberia': '1000171',
#  'Libya': '1000172',
#  'Liechtenstein': '7003515',
#  'Macao': '7486575',
#  'Madagascar': '7030367',
#  'Malawi': '7000726',
#  'Malaysia': '1000128',
#  'Maldives': '7000331',
#  'Mali': '7962678',
#  'Marshall Islands': '7016730',
#  'Mauritania': '1000176',
#  'Mauritius': '7000714',
#  'Mayotte': '7001669',
#  'Melilla': '7000462',
#  'Mexico': '7842005',
#  'Micronesia': '1010146',
#  'Moldova': '7006656',
#  'Mongolia': '7029379',
#  'Montenegro': '7750439',
#  'Montserrat': '7004786',
#  'Morocco': '7841890',
#  'Mozambique': '1000180',
#  'N Mariana Is': '7000552',
#  'Namibia': '1000198',
#  'Nauru': '7006158',
#  'Nepal': '1000132',
#  'New Caledonia': '1000223',
#  'New Zealand': '1000226',
#  'Nicaragua': '7005562',
#  'Niger': '1001912',
#  'Nigeria': '1000182',
#  'Niue Island': '7004687',
#  'Nl Antilles': '7004549',
#  'Norfolk Island': '7000430',
#  'North Korea': '1000122',
#  'Norway': '7835915',
#  'Occ Palest Terr': '7018359',
#  'Oman': '1000131',
#  'Pakistan': '1000133',
#  'Palau': '7005668',
#  'Panama': '7005565',
#  'Papua New Guinea': '7006160',
#  'Paraguay': '1000055',
#  'Peru': '1000056',
#  'Philippines': '1000135',
#  'Pitcairn': '7834446',
#  'Qatar': '1000136',
#  'Russia': '7002435',
#  'Rwanda': '7001682',
#  'Samoa': '1000239',
#  'San Marino': '7765926',
#  'Sao Tome-Princ.': '1000188',
#  'Saudi Arabia': '1000137',
#  'Senegal': '1000189',
#  'Serbia': '7006669',
#  'Seychelles': '1000190',
#  'Sierra Leone': '1000191',
#  'Singapore': '7000381',
#  'Solomon Islands': '1000233',
#  'Somalia': '1000192',
#  'South Africa': '1000193',
#  'South Georgia Is': '7005153',
#  'South Korea': '7000299',
#  'South Sudan': '7441551',
#  'Sri Lanka': '7030365',
#  'St Helena': '7799552',
#  'St Kitts & Nevis': '7005605',
#  'St Lucia': '7004772',
#  'St Pierre-Mique': '7005663',
#  'St Vincent': '7004773',
#  'Sudan': '7001604',
#  'Surinam': '7015386',
#  'Swaziland': '7001725',
#  'Switzerland': '7011731',
#  'Syria': '7879433',
#  'Taiwan': '1000141',
#  'Tajikistan': '7014835',
#  'Tanzania': '1000203',
#  'Thailand': '1000142',
#  'Timor-Leste': '7003703',
#  'Togo': '7792101',
#  'Tonga': '8047952',
#  'Trinidad:Tobago': '7004787',
#  'Tunisia': '1000205',
#  'Turkey': '7821365',
#  'Turkmenistan': '7006659',
#  'Turks & Caicos': '7004630',
#  'Tuvalu': '1000236',
#  'UAE': '1000143',
#  'US Minor Islands': '7023938',
#  'US Virgin Is': '7005118',
#  'Uganda': '1000206',
#  'Ukraine': '7006660',
#  'United States': '7012149',
#  'Uruguay': '1000058',
#  'Uzbekistan': '7006661',
#  'Vanuatu': '1000225',
#  'Vatican City': '7001168',
#  'Venezuela': '1000059',
#  'Vietnam': '1000145',
#  'Wallis & Futuna': '7006219',
#  'Western Sahara': '1000200',
#  'Yemen': '7000261',
#  'Zambia': '1000209',
#  'Zimbabwe': '1000185'}

# %% [markdown]
# Next, each CSV file needs a JSON metadata file so that a CSVW processor can understand how to convert to a linked data cube.
#
# At the same time, we copy across the CSV files, replacing the country string with the corresponding TGN ID. We also fill out a template JSON metadata file for each CSV file, putting the results in the `out` directory for further processing.

# %%
metadataTemplate = json.load(open('metadata/cn8_template.json'))

destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True)

for filename, google_id in sources:
    sourceFile = sourceFolder / filename
    
    table = pandas.read_csv(sourceFile)[:1000]
    table['country'] = table['country'].map(lambda x: tgn.get(x))
    destFile = destinationFolder / filename
    table[table.country != None].to_csv(destFile, index=False)
    metadataFile = destinationFolder / (filename + '-metadata.json')
    metadataTemplate['url'] = filename
    with open(metadataFile, 'w') as meta:
        json.dump(metadataTemplate, meta, indent=2)
