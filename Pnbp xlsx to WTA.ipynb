# %% [markdown]
# ###  pnbp xlsx to WTA

# %%
from databaker.framework import *

# %%
import pandas as pd

# %%
inputFile = 'pnbp.xlsx'

# %%
tab = loadxlstabs(inputFile)
# Out:
# Loading pnbp.xlsx which has size 424324 bytes
# Table names: ['data']

# %%
tab = tab[0]

# %%
observations = tab.excel_ref('B8').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
Title = tab.excel_ref('B1').expand(RIGHT).is_not_blank()

# %%
CDID = tab.excel_ref('B2').expand(RIGHT).is_not_blank()

# %%
Year = tab.excel_ref('A8').expand(DOWN).is_not_blank()

# %%
Currency = tab.excel_ref('P3')

# %%
Dimensions = [
            HDimConst('GEOG', 'K02000001'),
            HDim(Year,'TIME',DIRECTLY,LEFT),
            HDim(CDID,'Code Identifier',DIRECTLY,ABOVE),
            HDimConst('Currency', 'GBP(millions)'),            
            HDim(Title,'Title',DIRECTLY,ABOVE)
    
]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# savepreviewhtml(c1)

# %%
new_table = c1.topandas()
# Out:
# multiple TIMEUNITs: 'Year'(9495), 'Quarter'(37412)

# %%
new_table['Title'] = new_table['Title'].map(lambda cell:cell.replace('£m', ''))

# %%
new_table
# Out:
#              OBS       GEOG     TIME TIMEUNIT Code Identifier       Currency  \
# 0          194.0  K02000001     1946     Year            HMBN  GBP(millions)
# 1           76.0  K02000001     1946     Year            HMBM  GBP(millions)
# 2           56.0  K02000001     1946     Year            HMBP  GBP(millions)
# 3          118.0  K02000001     1946     Year            HMBO  GBP(millions)
# 4          181.0  K02000001     1946     Year            HBNT  GBP(millions)
# 5         -153.0  K02000001     1946     Year            HBOG  GBP(millions)
# 6         -101.0  K02000001     1946     Year            BOKI  GBP(millions)
# 7         1079.0  K02000001     1946     Year            BOKH  GBP(millions)
# 8          978.0  K02000001     1946     Year            BOKG  GBP(millions)
# 9          118.0  K02000001     1946     Year            HBOL  GBP(millions)
# 10         194.0  K02000001     1946     Year            HBOK  GBP(millions)
# 11          27.0  K02000001     1946     Year            FLYL  GBP(millions)
# 12          76.0  K02000001     1946     Year            HBOM  GBP(millions)
# 13        -153.0  K02000001     1946     Year            HBOP  GBP(millions)
# 14           0.0  K02000001     1946     Year            MT5W  GBP(millions)
# 15        -101.0  K02000001     1946     Year            LQCT  GBP(millions)
# 16         447.0  K02000001     1946     Year            IKBB  GBP(millions)
# 17         721.0  K02000001     1946     Year            IKBC  GBP(millions)
# 18         166.0  K02000001     1946     Year            KTNF  GBP(millions)
# 19        -274.0  K02000001     1946     Year            IKBD  GBP(millions)
# 20        1425.0  K02000001     1946     Year            IKBH  GBP(millions)
# 21        1800.0  K02000001     1946     Year            IKBI  GBP(millions)
# 22         267.0  K02000001     1946     Year            IKBN  GBP(millions)
# 23         101.0  K02000001     1946     Year            IKBO  GBP(millions)
# 24         166.0  K02000001     1946     Year            IKBP  GBP(millions)
# 25        -274.0  K02000001     1946     Year            KTMS  GBP(millions)
# 26         -20.0  K02000001     1946     Year            KTMP  GBP(millions)
# 27        -375.0  K02000001     1946     Year            KTMY  GBP(millions)
# 28         -21.0  K02000001     1946     Year            FKMJ  GBP(millions)
# 29         -20.0  K02000001     1946     Year            IJAJ  GBP(millions)
# ...          ...        ...      ...      ...             ...            ...
# 46877     1179.0  K02000001  2017 Q3  Quarter            MTN7  GBP(millions)
# 46878      838.0  K02000001  2017 Q3  Quarter            MTN8  GBP(millions)
# 46879    -1590.0  K02000001  2017 Q3  Quarter            ENIW  GBP(millions)
# 46880   -28029.0  K02000001  2017 Q3  Quarter            HJYM  GBP(millions)
# 46881     7346.0  K02000001  2017 Q3  Quarter            HJYR  GBP(millions)
# 46882      445.0  K02000001  2017 Q3  Quarter            FIOU  GBP(millions)
# 46883     5176.0  K02000001  2017 Q3  Quarter            FLUZ  GBP(millions)
# 46884      -15.0  K02000001  2017 Q3  Quarter            LTCV  GBP(millions)
# 46885     8895.0  K02000001  2017 Q3  Quarter            CYFV  GBP(millions)
# 46886     8539.0  K02000001  2017 Q3  Quarter            FAPO  GBP(millions)
# 46887    19996.0  K02000001  2017 Q3  Quarter            XBLW  GBP(millions)
# 46888    21588.0  K02000001  2017 Q3  Quarter            FEHH  GBP(millions)
# 46889    17173.0  K02000001  2017 Q3  Quarter            XBLX  GBP(millions)
# 46890      173.0  K02000001  2017 Q3  Quarter            BQKX  GBP(millions)
# 46891  1614796.0  K02000001  2017 Q3  Quarter            HEPX  GBP(millions)
# 46892    26032.0  K02000001  2017 Q3  Quarter            CGDZ  GBP(millions)
# 46893   -10453.0  K02000001  2017 Q3  Quarter            HDNY  GBP(millions)
# 46894    13385.0  K02000001  2017 Q3  Quarter            CGDX  GBP(millions)
# 46895     8428.0  K02000001  2017 Q3  Quarter            CGDW  GBP(millions)
# 46896    13551.0  K02000001  2017 Q3  Quarter            CGDV  GBP(millions)
# 46897     5377.0  K02000001  2017 Q3  Quarter            CGDU  GBP(millions)
# 46898     8174.0  K02000001  2017 Q3  Quarter            CGDT  GBP(millions)
# 46899     5176.0  K02000001  2017 Q3  Quarter            CGDS  GBP(millions)
# 46900        0.0  K02000001  2017 Q3  Quarter            CGDR  GBP(millions)
# 46901        0.0  K02000001  2017 Q3  Quarter            JCWM  GBP(millions)
# 46902     2519.0  K02000001  2017 Q3  Quarter            CGDP  GBP(millions)
# 46903     4784.0  K02000001  2017 Q3  Quarter            CGDO  GBP(millions)
# 46904      146.0  K02000001  2017 Q3  Quarter            CGDN  GBP(millions)
# 46905     5311.0  K02000001  2017 Q3  Quarter            FLUD  GBP(millions)
# 46906     6163.0  K02000001  2017 Q3  Quarter            FHME  GBP(millions)
#
#                                                    Title
# 0                     BoP Investment Income credits NSA
# 1                     BoP Investment Income Balance NSA
# 2                        BoP Primary Income Balance NSA
# 3                      BoP Investment Income debits NSA
# 4                            BoP FA total Net flows NSA
# 5                       BoP Current Account Balance NSA
# 6                BOP:Balance:CP SA:Total Trade in Goods
# 7      Balance of Payments:Imports:CP SA:Total Trade ...
# 8                BOP:Exports:CP SA:Total Trade in Goods
# 9                       BoP Investment Income Debits SA
# 10                     BoP Investment Income Credits SA
# 11               Capital Account (Debits) Total: CP SA:
# 12                     BoP Investment Income Balance SA
# 13                       BoP Current Account Balance SA
# 14                     Other Primary Income £M (Balance)
# 15               BOP:Balance:NSA:Total Trade in Goods £M
# 16          BOP: Exports:CP SA: Total Trade in Services
# 17            BOP:Imports:CP SA:Total Trade in Services
# 18         Secondary Income: Total: Balance: £M: CP: NSA
# 19           BOP:Balance:CP SA: Total Trade in Services
# 20     Balance of Payments: Trade in Goods & Services...
# 21     Balance of Payments: Trade in Goods & Services...
# 22           Secondary Income: Total exports: £M: CP: SA
# 23           Secondary Income: Total imports: £M: CP: SA
# 24            Secondary Income (BPM6) total bal. CP SA:
# 25     Balance of Payments: Total Trade in Services: ...
# 26          Income: Primary Income: Balance: £M: CP: NSA
# 27     Balance of Payments: Total Trade in Goods & Se...
# 28                      Capital Account: Balance: CP NSA
# 29     BOP: Income (BPM6) Primary Income balance CP SA:
# ...                                                  ...
# 46877  Manufacturing and Maintenance Services - Expor...
# 46878  Manufacturing and Maintenance Services - Balan...
# 46879  BOP: Trade in Goods:Fuels other than oil: SITC...
# 46880  FDI : Outward : Total FDI : Net Transactions i...
# 46881  FDI : Inward : Total FDI : Net Transactions in...
# 46882     Construction Services (Imports) Total: CP SA:
# 46883  Secondary Income: Other Sectors: Imports: £M: ...
# 46884  BoP: FA: Assets: Reserves: Total official rese...
# 46885  FDI : Inward : Total NFC & FCs : Re-invested E...
# 46886                    Travel (Exports) Total: CP SA:
# 46887  BoP: FA: PI: Liability flows: Total: Equity an...
# 46888   Other Business Services (Exports) Total: CP SA:
# 46889  IMF BoP FA PI liability flow debt securities 4...
# 46890        BOP:Balance:SA:Unspecified goods: SITC 9 £M
# 46891           BoP IIP PI Asset level total equity NSA
# 46892                              BoP Inc PI Debits SA
# 46893  FDI : Outward : Total NFC & FCs : Re-invested ...
# 46894              BoP Inc OI Debits Debt securities SA
# 46895                             BoP Inc OI Credits SA
# 46896                             BoP Inc PI Credits SA
# 46897       BoP Inc PI Credits total debt securities SA
# 46898     BoP Inc PI Credits total equity securities SA
# 46899  Secondary Income debits: Other sectors, other ...
# 46900  Secondary Income Debits; Other sectors payment...
# 46901  Capital transfers (Debits): Total other sector...
# 46902  Secondary Income debits; Central Government Ot...
# 46903  Secondary Income Credits: Other sectors, other...
# 46904  Secondary Income Credits: Central Govt Other r...
# 46905  Secondary Income: General Government: Imports:...
# 46906                 Transport (Imports) Total: CP SA:
#
# [46907 rows x 7 columns]

# %%
new_table = new_table.drop('TIMEUNIT', axis=1)

# %%
new_table
# Out:
#              OBS       GEOG     TIME Code Identifier       Currency  \
# 0          194.0  K02000001     1946            HMBN  GBP(millions)
# 1           76.0  K02000001     1946            HMBM  GBP(millions)
# 2           56.0  K02000001     1946            HMBP  GBP(millions)
# 3          118.0  K02000001     1946            HMBO  GBP(millions)
# 4          181.0  K02000001     1946            HBNT  GBP(millions)
# 5         -153.0  K02000001     1946            HBOG  GBP(millions)
# 6         -101.0  K02000001     1946            BOKI  GBP(millions)
# 7         1079.0  K02000001     1946            BOKH  GBP(millions)
# 8          978.0  K02000001     1946            BOKG  GBP(millions)
# 9          118.0  K02000001     1946            HBOL  GBP(millions)
# 10         194.0  K02000001     1946            HBOK  GBP(millions)
# 11          27.0  K02000001     1946            FLYL  GBP(millions)
# 12          76.0  K02000001     1946            HBOM  GBP(millions)
# 13        -153.0  K02000001     1946            HBOP  GBP(millions)
# 14           0.0  K02000001     1946            MT5W  GBP(millions)
# 15        -101.0  K02000001     1946            LQCT  GBP(millions)
# 16         447.0  K02000001     1946            IKBB  GBP(millions)
# 17         721.0  K02000001     1946            IKBC  GBP(millions)
# 18         166.0  K02000001     1946            KTNF  GBP(millions)
# 19        -274.0  K02000001     1946            IKBD  GBP(millions)
# 20        1425.0  K02000001     1946            IKBH  GBP(millions)
# 21        1800.0  K02000001     1946            IKBI  GBP(millions)
# 22         267.0  K02000001     1946            IKBN  GBP(millions)
# 23         101.0  K02000001     1946            IKBO  GBP(millions)
# 24         166.0  K02000001     1946            IKBP  GBP(millions)
# 25        -274.0  K02000001     1946            KTMS  GBP(millions)
# 26         -20.0  K02000001     1946            KTMP  GBP(millions)
# 27        -375.0  K02000001     1946            KTMY  GBP(millions)
# 28         -21.0  K02000001     1946            FKMJ  GBP(millions)
# 29         -20.0  K02000001     1946            IJAJ  GBP(millions)
# ...          ...        ...      ...             ...            ...
# 46877     1179.0  K02000001  2017 Q3            MTN7  GBP(millions)
# 46878      838.0  K02000001  2017 Q3            MTN8  GBP(millions)
# 46879    -1590.0  K02000001  2017 Q3            ENIW  GBP(millions)
# 46880   -28029.0  K02000001  2017 Q3            HJYM  GBP(millions)
# 46881     7346.0  K02000001  2017 Q3            HJYR  GBP(millions)
# 46882      445.0  K02000001  2017 Q3            FIOU  GBP(millions)
# 46883     5176.0  K02000001  2017 Q3            FLUZ  GBP(millions)
# 46884      -15.0  K02000001  2017 Q3            LTCV  GBP(millions)
# 46885     8895.0  K02000001  2017 Q3            CYFV  GBP(millions)
# 46886     8539.0  K02000001  2017 Q3            FAPO  GBP(millions)
# 46887    19996.0  K02000001  2017 Q3            XBLW  GBP(millions)
# 46888    21588.0  K02000001  2017 Q3            FEHH  GBP(millions)
# 46889    17173.0  K02000001  2017 Q3            XBLX  GBP(millions)
# 46890      173.0  K02000001  2017 Q3            BQKX  GBP(millions)
# 46891  1614796.0  K02000001  2017 Q3            HEPX  GBP(millions)
# 46892    26032.0  K02000001  2017 Q3            CGDZ  GBP(millions)
# 46893   -10453.0  K02000001  2017 Q3            HDNY  GBP(millions)
# 46894    13385.0  K02000001  2017 Q3            CGDX  GBP(millions)
# 46895     8428.0  K02000001  2017 Q3            CGDW  GBP(millions)
# 46896    13551.0  K02000001  2017 Q3            CGDV  GBP(millions)
# 46897     5377.0  K02000001  2017 Q3            CGDU  GBP(millions)
# 46898     8174.0  K02000001  2017 Q3            CGDT  GBP(millions)
# 46899     5176.0  K02000001  2017 Q3            CGDS  GBP(millions)
# 46900        0.0  K02000001  2017 Q3            CGDR  GBP(millions)
# 46901        0.0  K02000001  2017 Q3            JCWM  GBP(millions)
# 46902     2519.0  K02000001  2017 Q3            CGDP  GBP(millions)
# 46903     4784.0  K02000001  2017 Q3            CGDO  GBP(millions)
# 46904      146.0  K02000001  2017 Q3            CGDN  GBP(millions)
# 46905     5311.0  K02000001  2017 Q3            FLUD  GBP(millions)
# 46906     6163.0  K02000001  2017 Q3            FHME  GBP(millions)
#
#                                                    Title
# 0                     BoP Investment Income credits NSA
# 1                     BoP Investment Income Balance NSA
# 2                        BoP Primary Income Balance NSA
# 3                      BoP Investment Income debits NSA
# 4                            BoP FA total Net flows NSA
# 5                       BoP Current Account Balance NSA
# 6                BOP:Balance:CP SA:Total Trade in Goods
# 7      Balance of Payments:Imports:CP SA:Total Trade ...
# 8                BOP:Exports:CP SA:Total Trade in Goods
# 9                       BoP Investment Income Debits SA
# 10                     BoP Investment Income Credits SA
# 11               Capital Account (Debits) Total: CP SA:
# 12                     BoP Investment Income Balance SA
# 13                       BoP Current Account Balance SA
# 14                     Other Primary Income £M (Balance)
# 15               BOP:Balance:NSA:Total Trade in Goods £M
# 16          BOP: Exports:CP SA: Total Trade in Services
# 17            BOP:Imports:CP SA:Total Trade in Services
# 18         Secondary Income: Total: Balance: £M: CP: NSA
# 19           BOP:Balance:CP SA: Total Trade in Services
# 20     Balance of Payments: Trade in Goods & Services...
# 21     Balance of Payments: Trade in Goods & Services...
# 22           Secondary Income: Total exports: £M: CP: SA
# 23           Secondary Income: Total imports: £M: CP: SA
# 24            Secondary Income (BPM6) total bal. CP SA:
# 25     Balance of Payments: Total Trade in Services: ...
# 26          Income: Primary Income: Balance: £M: CP: NSA
# 27     Balance of Payments: Total Trade in Goods & Se...
# 28                      Capital Account: Balance: CP NSA
# 29     BOP: Income (BPM6) Primary Income balance CP SA:
# ...                                                  ...
# 46877  Manufacturing and Maintenance Services - Expor...
# 46878  Manufacturing and Maintenance Services - Balan...
# 46879  BOP: Trade in Goods:Fuels other than oil: SITC...
# 46880  FDI : Outward : Total FDI : Net Transactions i...
# 46881  FDI : Inward : Total FDI : Net Transactions in...
# 46882     Construction Services (Imports) Total: CP SA:
# 46883  Secondary Income: Other Sectors: Imports: £M: ...
# 46884  BoP: FA: Assets: Reserves: Total official rese...
# 46885  FDI : Inward : Total NFC & FCs : Re-invested E...
# 46886                    Travel (Exports) Total: CP SA:
# 46887  BoP: FA: PI: Liability flows: Total: Equity an...
# 46888   Other Business Services (Exports) Total: CP SA:
# 46889  IMF BoP FA PI liability flow debt securities 4...
# 46890        BOP:Balance:SA:Unspecified goods: SITC 9 £M
# 46891           BoP IIP PI Asset level total equity NSA
# 46892                              BoP Inc PI Debits SA
# 46893  FDI : Outward : Total NFC & FCs : Re-invested ...
# 46894              BoP Inc OI Debits Debt securities SA
# 46895                             BoP Inc OI Credits SA
# 46896                             BoP Inc PI Credits SA
# 46897       BoP Inc PI Credits total debt securities SA
# 46898     BoP Inc PI Credits total equity securities SA
# 46899  Secondary Income debits: Other sectors, other ...
# 46900  Secondary Income Debits; Other sectors payment...
# 46901  Capital transfers (Debits): Total other sector...
# 46902  Secondary Income debits; Central Government Ot...
# 46903  Secondary Income Credits: Other sectors, other...
# 46904  Secondary Income Credits: Central Govt Other r...
# 46905  Secondary Income: General Government: Imports:...
# 46906                 Transport (Imports) Total: CP SA:
#
# [46907 rows x 6 columns]

# %%
print(len(new_table))
# Out:
# 46907

# %%
new_table.fillna('', inplace=True)

writetechnicalCSV('C:\\Users\\vamsi\\Desktop\\Gdrive\\Out\\Mret\\pnbpWTA.csv', new_table)
# Out:
# writing 1 conversion segments into C:\Users\vamsi\Desktop\Gdrive\Out\Mret\pnbpWTA.csv
# pdconversionwrite segment size 46907
