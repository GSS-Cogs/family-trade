# %% [markdown]
# ###  Pinkbook2017_3.8

# %%
from databaker.framework import *

# %%
import pandas as pd

# %%
import io
import requests
from pathlib import Path

# %%
Url = 'https://drive.google.com/uc?export=download&id=16CpeYtvRxkvyt2RUkSAzTBGEJX_DnNLm'

# %%
df = pd.read_excel(Url, sheetname='3.8', header=None)

# %%
df
# Out:
#            0                                                  1      2     3   \
# 0         3.8                         Other business services1,2    NaN   NaN
# 1         NaN                                                NaN    NaN   NaN
# 2         NaN                                                NaN    NaN  1997
# 3         NaN                                                NaN    NaN   NaN
# 4                                              Exports (Credits)          NaN
# 5         NaN                                                NaN    NaN   NaN
# 6                                       Research and development   FJDP   754
# 7         NaN                                                NaN    NaN   NaN
# 8                 Professional and management consulting serv...          NaN
# 9                    Legal, accounting and management consulting          NaN
# 10                                                   Law society   FJGE   675
# ...

# %%
df.to_excel('PB2017_3.8.xls',index=False)

# %%
tab = loadxlstabs('PB2017_3.8.xls')
# Out:
# Loading PB2017_3.8.xls which has size 22016 bytes
# Table names: ['Sheet1']

# %%
tab = tab[0]
savepreviewhtml(tab)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# td.xb { font-weight: bold }
# td.xn { color: green }
# td.xd { color: purple }
# span.xo { text-decoration: line-through; }
# span.xn { }
# table { border-collapse: collapse }
# td.xc0 { background-color: Aqua }
# td.xc1 { background-color: LightGreen }
# td.xc2 { background-color: MistyRose }
# td.xc3 { background-color: LightGray }
# td.xc4 { background-color: BurlyWood }
# td.xc5 { background-color: Coral }
# td.xc6 { background-color: Gold }
# td.xc7 { background-color: Lime }
# td.xc8 { background-color: LightBlue }
# td.xc9 { background-color: Plum }
# td.xc10 { background-color: CornflowerBlue }
# td.xc11 { background-color: LightYellow }
# td.xc12 { background-color: Lavender }
# td.xc13 { background-color: Violet }
# td.xc14 { background-color: SeaGreen }
# td.xc15 { background-color: DeepSkyBlue }
# td.xc16 { background-color: Blue }
# ...

# %%
observations = tab.excel_ref('D8').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
Code = tab.excel_ref('C8').expand(DOWN).is_not_blank()

# %%
Year = tab.excel_ref('D4').expand(RIGHT).is_not_blank()

# %%
Commerce = tab.excel_ref('B').expand(DOWN).by_index([6,38,70]) - tab.excel_ref('B93').expand(DOWN)

# %%
Revenue = tab.excel_ref('B').expand(DOWN).is_not_blank().is_not_whitespace() - Commerce

# %%
Currency = tab.excel_ref('W3')

# %%
Dimensions = [
            HDimConst('GEOG', 'K02000001'),
            HDim(Year,'TIME', DIRECTLY,ABOVE),
            HDim(Code,'Cdid',DIRECTLY,LEFT),
            HDimConst('Currency', 'Pounds(millions)'),            
            HDim(Revenue, 'Revenue', DIRECTLY, LEFT),
            HDim(Commerce,'Commerce', CLOSEST, ABOVE)    
]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)

# %%
savepreviewhtml(c1)
# Out:
# <div id="injblock1002">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# td.xb { font-weight: bold }
# td.xn { color: green }
# td.xd { color: purple }
# span.xo { text-decoration: line-through; }
# span.xn { }
# table { border-collapse: collapse }
# td.xc0 { background-color: Aqua }
# td.xc1 { background-color: LightGreen }
# td.xc2 { background-color: MistyRose }
# td.xc3 { background-color: LightGray }
# td.xc4 { background-color: BurlyWood }
# td.xc5 { background-color: Coral }
# td.xc6 { background-color: Gold }
# td.xc7 { background-color: Lime }
# td.xc8 { background-color: LightBlue }
# td.xc9 { background-color: Plum }
# td.xc10 { background-color: CornflowerBlue }
# td.xc11 { background-color: LightYellow }
# td.xc12 { background-color: Lavender }
# td.xc13 { background-color: Violet }
# td.xc14 { background-color: SeaGreen }
# td.xc15 { background-color: DeepSkyBlue }
# td.xc16 { background-color: Blue }
# ...

# %%
new_table = c1.topandas()
new_table
# Out:
# TIMEUNIT='Year'
#         OBS DATAMARKER       GEOG  TIME TIMEUNIT   Cdid          Currency  \
# 0       754        NaN  K02000001  1997     Year   FJDP  Pounds(millions)
# 1      1425        NaN  K02000001  1998     Year   FJDP  Pounds(millions)
# 2      1745        NaN  K02000001  1999     Year   FJDP  Pounds(millions)
# 3      1307        NaN  K02000001  2000     Year   FJDP  Pounds(millions)
# 4      1760        NaN  K02000001  2001     Year   FJDP  Pounds(millions)
# 5      2458        NaN  K02000001  2002     Year   FJDP  Pounds(millions)
# 6      2986        NaN  K02000001  2003     Year   FJDP  Pounds(millions)
# 7      3945        NaN  K02000001  2004     Year   FJDP  Pounds(millions)
# 8      3596        NaN  K02000001  2005     Year   FJDP  Pounds(millions)
# 9      3698        NaN  K02000001  2006     Year   FJDP  Pounds(millions)
# 10     4031        NaN  K02000001  2007     Year   FJDP  Pounds(millions)
# ...

# %%
new_table = new_table.drop('TIMEUNIT', axis=1)
new_table = new_table.drop('DATAMARKER', axis=1)

# %%
new_table['Revenue'] = new_table['Revenue'].map(lambda cell:cell.replace('of which:', ''))

# %%
print(len(new_table))
new_table
# Out:
# 1040
#         OBS       GEOG  TIME   Cdid          Currency  \
# 0       754  K02000001  1997   FJDP  Pounds(millions)
# 1      1425  K02000001  1998   FJDP  Pounds(millions)
# 2      1745  K02000001  1999   FJDP  Pounds(millions)
# 3      1307  K02000001  2000   FJDP  Pounds(millions)
# 4      1760  K02000001  2001   FJDP  Pounds(millions)
# 5      2458  K02000001  2002   FJDP  Pounds(millions)
# 6      2986  K02000001  2003   FJDP  Pounds(millions)
# 7      3945  K02000001  2004   FJDP  Pounds(millions)
# 8      3596  K02000001  2005   FJDP  Pounds(millions)
# 9      3698  K02000001  2006   FJDP  Pounds(millions)
# 10     4031  K02000001  2007   FJDP  Pounds(millions)
# 11     4615  K02000001  2008   FJDP  Pounds(millions)
# 12     4024  K02000001  2009   FJDP  Pounds(millions)
# 13     4030  K02000001  2010   FJDP  Pounds(millions)
# 14     4162  K02000001  2011   FJDP  Pounds(millions)
# 15     5656  K02000001  2012   FJDP  Pounds(millions)
# ...

# %%
new_table['TIME'] = new_table['TIME'].str.strip()
new_table['GEOG'] = new_table['GEOG'].str.strip()
new_table['Currency'] = new_table['Currency'].str.strip()
new_table['Cdid'] = new_table['Cdid'].str.strip()

# %%
new_table['Commerce'] = new_table['Commerce'].str.strip()

# %%
new_table['Revenue'] = new_table['Revenue'].str.strip()

# %%
new_table.to_csv('C:\\Users\\vamsi\\Desktop\\Gdrive\\Out\\Mret\\pinkbook2017chapter3_3.8.tidydata.csv', index = False)
