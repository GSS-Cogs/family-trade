# %% [markdown]
# ###  Pinkbook2017_3.5

# %%
from databaker.framework import *
import pandas as pd

# %% [markdown]
# Use common 'fetch_sources' notebook to get a local copy of all source data.

# %%
# %run 'fetch_sources.ipynb'

# %%
tab = loadxlstabs(pbFile, sheetids='3.5')[0]
savepreviewhtml(tab)
# Out:
# <div id="injblock1006">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# td.xb { font-weight: bold }
# td.xn { color: green }
# td.xd { color: purple }
# span.xo { text-decoration: line-through; }
# span.xn { }
# table { border-collapse: collapse }
# td.xc0 { background-color: Aqua }
# td.xc1 { background-color: LightGreen }
# td.xc2 { background-color: MistyRose }
# td.xc3 { background-color: LightGray }
# td.xc4 { background-color: BurlyWood }
# td.xc5 { background-color: Coral }
# td.xc6 { background-color: Gold }
# td.xc7 { background-color: Lime }
# td.xc8 { background-color: LightBlue }
# td.xc9 { background-color: Plum }
# td.xc10 { background-color: CornflowerBlue }
# td.xc11 { background-color: LightYellow }
# td.xc12 { background-color: Lavender }
# td.xc13 { background-color: Violet }
# td.xc14 { background-color: SeaGreen }
# td.xc15 { background-color: DeepSkyBlue }
# td.xc16 { background-color: Blue }
# ...

# %%
observations = tab.excel_ref('D8').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
Code = tab.excel_ref('C8').expand(DOWN).is_not_blank()

# %%
Year = tab.excel_ref('D3').expand(RIGHT).is_not_blank()

# %%
Commerce = tab.excel_ref('B').expand(DOWN).by_index([5,39,59]) - tab.excel_ref('B72').expand(DOWN)

# %%
Financialservices = tab.excel_ref('B').expand(DOWN).by_index([7,28,37,41,50,57,61,68,70,71]) - tab.excel_ref('B72').expand(DOWN)

# %%
Revenue = tab.excel_ref('B').expand(DOWN).is_not_blank().is_not_whitespace() - Commerce - Financialservices - tab.excel_ref('B1').expand(UP)

# %%
Currency = tab.excel_ref('W2')

# %%
Dimensions = [
            HDimConst('GEOG', 'K02000001'),
            HDim(Year,'TIME', DIRECTLY,ABOVE),
            HDim(Code,'Cdid',DIRECTLY,LEFT),
            HDimConst('Currency', 'Pounds(millions)'),            
            HDim(Revenue, 'Revenue', DIRECTLY, LEFT),
            HDim(Financialservices, 'Financial Services', CLOSEST, ABOVE),
            HDim(Commerce,'Commerce', CLOSEST, ABOVE)    
]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)

# %%
savepreviewhtml(c1)
# Out:
# <div id="injblock1009">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# td.xb { font-weight: bold }
# td.xn { color: green }
# td.xd { color: purple }
# span.xo { text-decoration: line-through; }
# span.xn { }
# table { border-collapse: collapse }
# td.xc0 { background-color: Aqua }
# td.xc1 { background-color: LightGreen }
# td.xc2 { background-color: MistyRose }
# td.xc3 { background-color: LightGray }
# td.xc4 { background-color: BurlyWood }
# td.xc5 { background-color: Coral }
# td.xc6 { background-color: Gold }
# td.xc7 { background-color: Lime }
# td.xc8 { background-color: LightBlue }
# td.xc9 { background-color: Plum }
# td.xc10 { background-color: CornflowerBlue }
# td.xc11 { background-color: LightYellow }
# td.xc12 { background-color: Lavender }
# td.xc13 { background-color: Violet }
# td.xc14 { background-color: SeaGreen }
# td.xc15 { background-color: DeepSkyBlue }
# td.xc16 { background-color: Blue }
# ...

# %%
new_table = c1.topandas()
new_table
# Out:
# TIMEUNIT='Year'
#          OBS       GEOG  TIME TIMEUNIT   Cdid          Currency  \
# 0      904.0  K02000001  1997     Year   FNMM  Pounds(millions)
# 1      849.0  K02000001  1998     Year   FNMM  Pounds(millions)
# 2      866.0  K02000001  1999     Year   FNMM  Pounds(millions)
# 3      868.0  K02000001  2000     Year   FNMM  Pounds(millions)
# 4      853.0  K02000001  2001     Year   FNMM  Pounds(millions)
# 5     1045.0  K02000001  2002     Year   FNMM  Pounds(millions)
# 6     1528.0  K02000001  2003     Year   FNMM  Pounds(millions)
# 7     1925.0  K02000001  2004     Year   FNMM  Pounds(millions)
# 8     2632.0  K02000001  2005     Year   FNMM  Pounds(millions)
# 9     3199.0  K02000001  2006     Year   FNMM  Pounds(millions)
# 10    4856.0  K02000001  2007     Year   FNMM  Pounds(millions)
# 11    5035.0  K02000001  2008     Year   FNMM  Pounds(millions)
# 12    3590.0  K02000001  2009     Year   FNMM  Pounds(millions)
# ...

# %%
new_table = new_table.drop('TIMEUNIT', axis=1)

# %%
print(len(new_table))
new_table
# Out:
# 680
#          OBS       GEOG  TIME   Cdid          Currency  \
# 0      904.0  K02000001  1997   FNMM  Pounds(millions)
# 1      849.0  K02000001  1998   FNMM  Pounds(millions)
# 2      866.0  K02000001  1999   FNMM  Pounds(millions)
# 3      868.0  K02000001  2000   FNMM  Pounds(millions)
# 4      853.0  K02000001  2001   FNMM  Pounds(millions)
# 5     1045.0  K02000001  2002   FNMM  Pounds(millions)
# 6     1528.0  K02000001  2003   FNMM  Pounds(millions)
# 7     1925.0  K02000001  2004   FNMM  Pounds(millions)
# 8     2632.0  K02000001  2005   FNMM  Pounds(millions)
# 9     3199.0  K02000001  2006   FNMM  Pounds(millions)
# 10    4856.0  K02000001  2007   FNMM  Pounds(millions)
# 11    5035.0  K02000001  2008   FNMM  Pounds(millions)
# 12    3590.0  K02000001  2009   FNMM  Pounds(millions)
# 13    4405.0  K02000001  2010   FNMM  Pounds(millions)
# 14    4279.0  K02000001  2011   FNMM  Pounds(millions)
# 15    5254.0  K02000001  2012   FNMM  Pounds(millions)
# ...

# %%
new_table['Financial Services'] = new_table['Financial Services'].map(lambda x: x.rstrip('123'))

# %%
new_table
# Out:
#          OBS       GEOG  TIME   Cdid          Currency  \
# 0      904.0  K02000001  1997   FNMM  Pounds(millions)
# 1      849.0  K02000001  1998   FNMM  Pounds(millions)
# 2      866.0  K02000001  1999   FNMM  Pounds(millions)
# 3      868.0  K02000001  2000   FNMM  Pounds(millions)
# 4      853.0  K02000001  2001   FNMM  Pounds(millions)
# 5     1045.0  K02000001  2002   FNMM  Pounds(millions)
# 6     1528.0  K02000001  2003   FNMM  Pounds(millions)
# 7     1925.0  K02000001  2004   FNMM  Pounds(millions)
# 8     2632.0  K02000001  2005   FNMM  Pounds(millions)
# 9     3199.0  K02000001  2006   FNMM  Pounds(millions)
# 10    4856.0  K02000001  2007   FNMM  Pounds(millions)
# 11    5035.0  K02000001  2008   FNMM  Pounds(millions)
# 12    3590.0  K02000001  2009   FNMM  Pounds(millions)
# 13    4405.0  K02000001  2010   FNMM  Pounds(millions)
# 14    4279.0  K02000001  2011   FNMM  Pounds(millions)
# 15    5254.0  K02000001  2012   FNMM  Pounds(millions)
# ...

# %%
new_table['Revenue'] = new_table['Revenue'].fillna('')

# %%
new_table['Revenue'] = new_table['Revenue'].map(lambda x: x.rstrip('23'))

# %%
new_table
# Out:
#          OBS       GEOG  TIME   Cdid          Currency  \
# 0      904.0  K02000001  1997   FNMM  Pounds(millions)
# 1      849.0  K02000001  1998   FNMM  Pounds(millions)
# 2      866.0  K02000001  1999   FNMM  Pounds(millions)
# 3      868.0  K02000001  2000   FNMM  Pounds(millions)
# 4      853.0  K02000001  2001   FNMM  Pounds(millions)
# 5     1045.0  K02000001  2002   FNMM  Pounds(millions)
# 6     1528.0  K02000001  2003   FNMM  Pounds(millions)
# 7     1925.0  K02000001  2004   FNMM  Pounds(millions)
# 8     2632.0  K02000001  2005   FNMM  Pounds(millions)
# 9     3199.0  K02000001  2006   FNMM  Pounds(millions)
# 10    4856.0  K02000001  2007   FNMM  Pounds(millions)
# 11    5035.0  K02000001  2008   FNMM  Pounds(millions)
# 12    3590.0  K02000001  2009   FNMM  Pounds(millions)
# 13    4405.0  K02000001  2010   FNMM  Pounds(millions)
# 14    4279.0  K02000001  2011   FNMM  Pounds(millions)
# 15    5254.0  K02000001  2012   FNMM  Pounds(millions)
# ...

# %%
new_table['TIME'] = new_table['TIME'].str.strip()
new_table['GEOG'] = new_table['GEOG'].str.strip()
new_table['Currency'] = new_table['Currency'].str.strip()
new_table['Cdid'] = new_table['Cdid'].str.strip()

# %%
new_table['Commerce'] = new_table['Commerce'].str.strip()

# %%
new_table['Revenue'] = new_table['Revenue'].str.strip()

# %%
new_table['Financial Services'] = new_table['Financial Services'].str.strip()

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True)

pbCSV = destinationFolder / (Path(pbFilename).stem + '_3.3.csv')

new_table.to_csv(pbCSV, index = False)
new_table.to_csv('C:\\Users\\vamsi\\Desktop\\Gdrive\\Out\\Mret\\pinkbook2017chapter3_3.5.tidydata.csv', index = False)
