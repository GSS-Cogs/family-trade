# %% [markdown]
# ###  Pinkbook2017_3.2

# %%
from databaker.framework import *

# %%
import pandas as pd

# %%
import io
import requests
from pathlib import Path

# %%
Url = 'https://drive.google.com/uc?export=download&id=16CpeYtvRxkvyt2RUkSAzTBGEJX_DnNLm'

# %%
df = pd.read_excel(Url, sheetname='3.2', header=None)

# %%
df
# Out:
#             0                                                  1      2   \
# 0          3.2                                          Transport    NaN
# 1          NaN                                                NaN    NaN
# 2          NaN                                                NaN    NaN
# 3          NaN                                                NaN    NaN
# 4                                               Exports (Credits)
# 5          NaN                                                NaN    NaN
# 6                                                   Sea transport
# 7          NaN                                                NaN    NaN
# 8                                                       Passenger
# 9                                               Passenger revenue   FJAL
# 10                                          Time charter receipts   FJAM
# 11                                                                   NaN
# ...

# %%
df.to_excel('PB2017_3.2.xls',index=False)

# %%
tab = loadxlstabs('PB2017_3.2.xls')
# Out:
# Loading PB2017_3.2.xls which has size 34304 bytes
# Table names: ['Sheet1']

# %%
tab = tab[0]
savepreviewhtml(tab)
# Out:
# <div id="injblock1004">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# td.xb { font-weight: bold }
# td.xn { color: green }
# td.xd { color: purple }
# span.xo { text-decoration: line-through; }
# span.xn { }
# table { border-collapse: collapse }
# td.xc0 { background-color: Aqua }
# td.xc1 { background-color: LightGreen }
# td.xc2 { background-color: MistyRose }
# td.xc3 { background-color: LightGray }
# td.xc4 { background-color: BurlyWood }
# td.xc5 { background-color: Coral }
# td.xc6 { background-color: Gold }
# td.xc7 { background-color: Lime }
# td.xc8 { background-color: LightBlue }
# td.xc9 { background-color: Plum }
# td.xc10 { background-color: CornflowerBlue }
# td.xc11 { background-color: LightYellow }
# td.xc12 { background-color: Lavender }
# td.xc13 { background-color: Violet }
# td.xc14 { background-color: SeaGreen }
# td.xc15 { background-color: DeepSkyBlue }
# td.xc16 { background-color: Blue }
# ...

# %%
observations = tab.excel_ref('D10').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
Code = tab.excel_ref('C10').expand(DOWN).is_not_blank()

# %%
Year = tab.excel_ref('D4').expand(RIGHT).is_not_blank()

# %%
Commerce = tab.excel_ref('B').expand(DOWN).by_index([6,67,129]) - tab.excel_ref('B184').expand(DOWN)

# %%
Modeoftransport = tab.excel_ref('B').expand(DOWN).by_index([8,32,46,52,58,60,62,64,69,98,104,108,112,114,118,
                                                            120,122,124,126,131,135,142,149,152,153,155,165,171,177,179,181,183])

# %%
Modeoftransport = Modeoftransport - tab.excel_ref('B184').expand(DOWN)

# %%
Services = tab.excel_ref('B').expand(DOWN).by_index([10,17,21,26,28,30,34,35,37,38,40,42,44,64,71,78,82,86,88,90,94,96,98,106,
                                                     126,131,155,163,183]) - tab.excel_ref('B184').expand(DOWN)

# %%
Typeoftransport = tab.excel_ref('B').expand(DOWN).is_not_blank().is_not_whitespace() -Services - Modeoftransport - tab.excel_ref('B2').expand(UP)

# %%
Currency = tab.excel_ref('W2')

# %%
Dimensions = [
            HDimConst('GEOG', 'K02000001'),
            HDim(Year,'Year', DIRECTLY,ABOVE),
            HDim(Code,'Code Identifier',DIRECTLY,LEFT),
            HDimConst('Currency', 'Pounds(millions)'),            
            HDim(Typeoftransport, 'Revenue', DIRECTLY, LEFT),
            HDim(Services, 'Services', CLOSEST, ABOVE),
            HDim(Modeoftransport, 'Mode of Transport', CLOSEST, ABOVE),
            HDim(Commerce, 'Commerce', CLOSEST, ABOVE)
    
]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)

# %%
savepreviewhtml(c1)
# Out:
# <div id="injblock1033">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# td.xb { font-weight: bold }
# td.xn { color: green }
# td.xd { color: purple }
# span.xo { text-decoration: line-through; }
# span.xn { }
# table { border-collapse: collapse }
# td.xc0 { background-color: Aqua }
# td.xc1 { background-color: LightGreen }
# td.xc2 { background-color: MistyRose }
# td.xc3 { background-color: LightGray }
# td.xc4 { background-color: BurlyWood }
# td.xc5 { background-color: Coral }
# td.xc6 { background-color: Gold }
# td.xc7 { background-color: Lime }
# td.xc8 { background-color: LightBlue }
# td.xc9 { background-color: Plum }
# td.xc10 { background-color: CornflowerBlue }
# td.xc11 { background-color: LightYellow }
# td.xc12 { background-color: Lavender }
# td.xc13 { background-color: Violet }
# td.xc14 { background-color: SeaGreen }
# td.xc15 { background-color: DeepSkyBlue }
# td.xc16 { background-color: Blue }
# ...

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS DATAMARKER       GEOG    Year Code Identifier          Currency  \
# 0      688        NaN  K02000001  1997.0            FJAL  Pounds(millions)
# 1      462        NaN  K02000001  1998.0            FJAL  Pounds(millions)
# 2      454        NaN  K02000001  1999.0            FJAL  Pounds(millions)
# 3      622        NaN  K02000001  2000.0            FJAL  Pounds(millions)
# 4      488        NaN  K02000001  2001.0            FJAL  Pounds(millions)
# 5      558        NaN  K02000001  2002.0            FJAL  Pounds(millions)
# 6      993        NaN  K02000001  2003.0            FJAL  Pounds(millions)
# 7      810        NaN  K02000001  2004.0            FJAL  Pounds(millions)
# 8      557        NaN  K02000001  2005.0            FJAL  Pounds(millions)
# 9      407        NaN  K02000001  2006.0            FJAL  Pounds(millions)
# 10     357        NaN  K02000001  2007.0            FJAL  Pounds(millions)
# ...

# %%
new_table = new_table.drop('DATAMARKER', axis=1)

# %%
new_table['TIME'] = new_table['Year'].map(lambda cell:cell.replace('.0', ''))
new_table
# Out:
#        OBS       GEOG    Year Code Identifier          Currency  \
# 0      688  K02000001  1997.0            FJAL  Pounds(millions)
# 1      462  K02000001  1998.0            FJAL  Pounds(millions)
# 2      454  K02000001  1999.0            FJAL  Pounds(millions)
# 3      622  K02000001  2000.0            FJAL  Pounds(millions)
# 4      488  K02000001  2001.0            FJAL  Pounds(millions)
# 5      558  K02000001  2002.0            FJAL  Pounds(millions)
# 6      993  K02000001  2003.0            FJAL  Pounds(millions)
# 7      810  K02000001  2004.0            FJAL  Pounds(millions)
# 8      557  K02000001  2005.0            FJAL  Pounds(millions)
# 9      407  K02000001  2006.0            FJAL  Pounds(millions)
# 10     357  K02000001  2007.0            FJAL  Pounds(millions)
# 11     394  K02000001  2008.0            FJAL  Pounds(millions)
# 12     546  K02000001  2009.0            FJAL  Pounds(millions)
# 13     791  K02000001  2010.0            FJAL  Pounds(millions)
# ...

# %%
new_table = new_table.drop('Year', axis=1)

# %%
print(len(new_table))
new_table
# Out:
# 1620
#        OBS       GEOG Code Identifier          Currency  \
# 0      688  K02000001            FJAL  Pounds(millions)
# 1      462  K02000001            FJAL  Pounds(millions)
# 2      454  K02000001            FJAL  Pounds(millions)
# 3      622  K02000001            FJAL  Pounds(millions)
# 4      488  K02000001            FJAL  Pounds(millions)
# 5      558  K02000001            FJAL  Pounds(millions)
# 6      993  K02000001            FJAL  Pounds(millions)
# 7      810  K02000001            FJAL  Pounds(millions)
# 8      557  K02000001            FJAL  Pounds(millions)
# 9      407  K02000001            FJAL  Pounds(millions)
# 10     357  K02000001            FJAL  Pounds(millions)
# 11     394  K02000001            FJAL  Pounds(millions)
# 12     546  K02000001            FJAL  Pounds(millions)
# 13     791  K02000001            FJAL  Pounds(millions)
# 14    1291  K02000001            FJAL  Pounds(millions)
# 15    1267  K02000001            FJAL  Pounds(millions)
# ...

# %%
new_table['Mode of Transport'] = new_table['Mode of Transport'].map(lambda x: x.rstrip('12'))

# %%
new_table
# Out:
#        OBS       GEOG Code Identifier          Currency  \
# 0      688  K02000001            FJAL  Pounds(millions)
# 1      462  K02000001            FJAL  Pounds(millions)
# 2      454  K02000001            FJAL  Pounds(millions)
# 3      622  K02000001            FJAL  Pounds(millions)
# 4      488  K02000001            FJAL  Pounds(millions)
# 5      558  K02000001            FJAL  Pounds(millions)
# 6      993  K02000001            FJAL  Pounds(millions)
# 7      810  K02000001            FJAL  Pounds(millions)
# 8      557  K02000001            FJAL  Pounds(millions)
# 9      407  K02000001            FJAL  Pounds(millions)
# 10     357  K02000001            FJAL  Pounds(millions)
# 11     394  K02000001            FJAL  Pounds(millions)
# 12     546  K02000001            FJAL  Pounds(millions)
# 13     791  K02000001            FJAL  Pounds(millions)
# 14    1291  K02000001            FJAL  Pounds(millions)
# 15    1267  K02000001            FJAL  Pounds(millions)
# ...

# %%
new_table.fillna('', inplace=True)

writetechnicalCSV('C:\\Users\\vamsi\\Desktop\\Gdrive\\Out\\Mret\\pinkbook2017chapter3_3.2.csv', new_table)
# Out:
# writing 1 conversion segments into C:\Users\vamsi\Desktop\Gdrive\Out\Mret\pinkbook2017chapter3_3.2.csv
# pdconversionwrite segment size 1620

# %%
DF = pd.read_csv('C:\\Users\\vamsi\\Desktop\\Gdrive\\Out\\Mret\\pinkbook2017chapter3_3.2.csv')

# %%
DF
# Out:
#      observation  data_marking  statistical_unit_eng  statistical_unit_cym  \
# 0          688.0           NaN                   NaN                   NaN
# 1          462.0           NaN                   NaN                   NaN
# 2          454.0           NaN                   NaN                   NaN
# 3          622.0           NaN                   NaN                   NaN
# 4          488.0           NaN                   NaN                   NaN
# 5          558.0           NaN                   NaN                   NaN
# 6          993.0           NaN                   NaN                   NaN
# 7          810.0           NaN                   NaN                   NaN
# 8          557.0           NaN                   NaN                   NaN
# 9          407.0           NaN                   NaN                   NaN
# 10         357.0           NaN                   NaN                   NaN
# ...

# %%
DF.drop('cdid', axis =1, inplace = True)
DF.drop('unit_multiplier', axis =1, inplace = True)

# %%
DF.drop(['dim_id_1','dimension_label_eng_1',
        'dimension_label_cym_1', 'dimension_item_label_eng_1', 
        'dimension_item_label_cym_1' ,    
        'dim_id_2', 'dimension_label_eng_2', 
        'dimension_item_label_eng_2','dimension_item_label_cym_2','is_total_1','is_sub_total_1',
        'time_dim_item_label_eng','time_dim_item_label_cym' ],
         axis = 1, inplace =True)

# %%
DF.rename(index=str, columns={"dim_item_id_1": "cdid"}, inplace = True)

# %%
DF.rename(index=str, columns={"dim_item_id_2": "unit_multiplier"}, inplace = True)

# %%
DF['dimension_item_label_eng_1'] = ''

# %%
DF.to_csv('C:\\Users\\vamsi\\Desktop\\Gdrive\\Out\\Mret\\pinkbook2017chapter3_3.2.csv', index = False)
